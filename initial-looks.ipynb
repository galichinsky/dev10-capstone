# %%
import pandas as pd
print(pd.__version__)

df_QOL = pd.read_csv('Quality_of_Life.csv')
df_QOL.dropna(inplace=True)
df_QOL
# Out:
# 2.2.3
#            country  Purchasing Power Value Purchasing Power Category  \
# 2          Albania                   42.82                     'Low'
# 4          Algeria                   27.60                'Very Low'
# 10       Argentina                   40.36                     'Low'
# 11         Armenia                   36.91                'Very Low'
# 13       Australia                  137.58               'Very High'
# ..             ...                     ...                       ...
# 223  United States                  153.02               'Very High'
# 224        Uruguay                   57.92                     'Low'
# 226     Uzbekistan                   44.66                     'Low'
# 230        Vietnam                   44.49                     'Low'
# 235       Zimbabwe                   28.76                'Very Low'
#
#      Safety Value Safety Category  Health Care Value Health Care Category  \
# ...

# %%
df_WHR = pd.read_csv('World-happiness-report-2024.csv')
df_WHR.dropna(inplace=True)
df_WHR
# Out:
#          Country name            Regional indicator  Ladder score  \
# 0             Finland                Western Europe         7.741
# 1             Denmark                Western Europe         7.583
# 2             Iceland                Western Europe         7.525
# 3              Sweden                Western Europe         7.344
# 4              Israel  Middle East and North Africa         7.341
# ..                ...                           ...           ...
# 138  Congo (Kinshasa)            Sub-Saharan Africa         3.295
# 139      Sierra Leone            Sub-Saharan Africa         3.245
# 140           Lesotho            Sub-Saharan Africa         3.186
# 141           Lebanon  Middle East and North Africa         2.707
# 142       Afghanistan                    South Asia         1.721
#
#      upperwhisker  lowerwhisker  Log GDP per capita  Social support  \
# 0           7.815         7.667               1.844           1.572
# ...
