# %%
import pandas as pd
print(pd.__version__)

df_QOL = pd.read_csv('Quality_of_Life.csv')
df_QOL.dropna(inplace=True)
df_QOL = df_QOL.apply(lambda s: s.str.replace("'", '', regex=False) if s.dtype == "object" else s)
# rename columns
df_QOL.columns = ['country', 'purchasing_power_val', 'purchasing_power_cat', 'safety_value', 'safety_cat', 'healthcare_value', 'healthcare_cat', 'climate_val', 'climate_cat', 'cost_of_living_val', 'cost_of_living_cat', 'property_price_income_val', 'property_price_income_cat', 'traffic_commute_time_val', 'traffic_commute_time_cat', 'pollution_val', 'pollution_cat', 'quality_of_life_val', 'quality_of_life_cat']

# Remove ':' from the 'quality_of_life_val' column
df_QOL['quality_of_life_val'] = df_QOL['quality_of_life_val'].str.replace(':', '', regex=False)
df_QOL.info()
df_QOL.head()
# Out:
# 2.2.3
# <class 'pandas.core.frame.DataFrame'>
# Index: 114 entries, 2 to 235
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   country                    114 non-null    object
#  1   purchasing_power_val       114 non-null    float64
#  2   purchasing_power_cat       114 non-null    object
#  3   safety_value               114 non-null    float64
#  4   safety_cat                 114 non-null    object
#  5   healthcare_value           114 non-null    float64
#  6   healthcare_cat             114 non-null    object
#  7   climate_val                114 non-null    float64
#  8   climate_cat                114 non-null    object
#  9   cost_of_living_val         114 non-null    float64
#  10  cost_of_living_cat         114 non-null    object
#  11  property_price_income_val  114 non-null    object
#  12  property_price_income_cat  114 non-null    object
# ...

# %%
df_WHR = pd.read_csv('World-happiness-report-2024.csv')
df_WHR.dropna(inplace=True)
df_WHR.columns = ['country', 'region', 'ladder_score', 'upperwhisker', 'lowerwhisker', 'log_gdp', 'social_support', 'healthy_life_expectancy', 'freedom', 'generosity', 'perceptions_of_corruption', 'dystopia_residual']
df_WHR.info()
df_WHR.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 140 entries, 0 to 142
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   country                    140 non-null    object
#  1   region                     140 non-null    object
#  2   ladder_score               140 non-null    float64
#  3   upperwhisker               140 non-null    float64
#  4   lowerwhisker               140 non-null    float64
#  5   log_gdp                    140 non-null    float64
#  6   social_support             140 non-null    float64
#  7   healthy_life_expectancy    140 non-null    float64
#  8   freedom                    140 non-null    float64
#  9   generosity                 140 non-null    float64
#  10  perceptions_of_corruption  140 non-null    float64
#  11  dystopia_residual          140 non-null    float64
# dtypes: float64(10), object(2)
# memory usage: 14.2+ KB
# ...
